# %%
import numpy as np
items = list(np.load('newdata/items.npy', allow_pickle=True))
items.sort()
print(len(items))
items
# Out:
# 68433
# [6,
#  15,
#  16,
#  17,
#  19,
#  25,
#  26,
#  32,
#  33,
#  40,
#  42,
#  54,
#  55,
#  66,
#  71,
#  98,
#  102,
#  119,
#  123,
#  124,
#  137,
#  138,
#  147,
#  152,
#  155,
#  168,
#  174,
#  185,
#  189,
#  190,
#  193,
#  199,
#  204,
#  211,
#  212,
#  217,
#  233,
#  247,
#  257,
#  261,
#  274,
#  301,
#  303,
#  304,
#  305,
#  307,
#  313,
#  315,
#  316,
#  320,
#  321,
#  334,
#  342,
#  348,
#  350,
#  361,
#  371,
#  376,
#  379,
#  381,
#  387,
#  388,
#  393,
#  396,
#  402,
#  403,
#  404,
#  412,
#  433,
#  441,
#  452,
#  456,
#  460,
#  465,
#  466,
#  484,
#  485,
#  490,
#  496,
#  498,
#  499,
#  502,
#  506,
#  538,
#  545,
#  546,
#  547,
#  549,
#  550,
#  556,
#  563,
#  565,
#  566,
#  572,
#  594,
#  596,
#  602,
#  609,
#  617,
#  618,
#  635,
#  638,
#  651,
#  655,
#  659,
#  660,
#  668,
#  671,
#  676,
#  677,
#  678,
#  689,
#  693,
#  696,
#  697,
#  698,
#  714,
#  720,
#  726,
#  733,
#  743,
#  749,
#  762,
#  766,
#  779,
#  780,
# ...
